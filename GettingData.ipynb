# %%
# %pylab inline
import IPython
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #Bolshoi data in CosmoSim

# %%
IPython.display.VimeoVideo(21866269)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://player.vimeo.com/video/21866269"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IPython.display.Image("img/cosmosim.png")

# %%
from astroquery.cosmosim import CosmoSim
# Out:
# WARNING: AstropyDeprecationWarning: Config parameter 'auto_colname' in section [table.column] of the file '/Users/forero/.astropy/config/astropy.cfg' is deprecated. Use 'auto_colname' in section [table] instead. [astropy.config.configuration]
# WARNING:astropy:AstropyDeprecationWarning: Config parameter 'auto_colname' in section [table.column] of the file '/Users/forero/.astropy/config/astropy.cfg' is deprecated. Use 'auto_colname' in section [table] instead.

# %%
CS = CosmoSim()

# %%
CS.login(username="forero",store_password=True)
# Out:
# WARNING: Using the password found in the keychain for the provided username. [astroquery.cosmosim.core]
# WARNING:astropy:Using the password found in the keychain for the provided username.
# Authenticating forero on www.cosmosim.org...
# Authentication successful!
# <Response [200]>

# %%
CS.check_login_status()
# Out:
# Status: You are logged in as forero.

# %%
sql_query="SELECT DISTINCT * FROM Bolshoi.Redshifts ORDER BY snapnum DESC"

# %%
job_id = CS.run_sql_query(query_string=sql_query)
# Out:
# Job created: 364989887366449

# %%
data = CS.download(jobid=job_id,format='csv')

# %%
header = data[0]
data_points = array(data[1])
print header
for line in data_points:
    print line
# Out:
# ['row_id', 'Bolshoi__Redshifts__snapnum', 'Bolshoi__Redshifts__aexp', 'Bolshoi__Redshifts__zred']
# [   1.  416.    1.    0.]
# [  2.00000000e+00   4.15000000e+02   9.97350000e-01   2.65700000e-03]
# [  3.00000000e+00   4.14000000e+02   9.94350000e-01   5.68200000e-03]
# [  4.00000000e+00   4.13000000e+02   9.91350000e-01   8.72500000e-03]
# [  5.00000000e+00   4.12000000e+02   9.88350000e-01   1.17870000e-02]
# [  6.00000000e+00   4.11000000e+02   9.85350000e-01   1.48680000e-02]
# [  7.00000000e+00   4.10000000e+02   9.82350000e-01   1.79670000e-02]
# [  8.00000000e+00   4.09000000e+02   9.79350000e-01   2.10850000e-02]
# [  9.00000000e+00   4.08000000e+02   9.76350000e-01   2.42230000e-02]
# [  1.00000000e+01   4.07000000e+02   9.73350000e-01   2.73800000e-02]
# [  1.10000000e+01   4.06000000e+02   9.70350000e-01   3.05560000e-02]
# [  1.20000000e+01   4.05000000e+02   9.67350000e-01   3.37520000e-02]
# [  1.30000000e+01   4.04000000e+02   9.64350000e-01   3.69680000e-02]
# [  1.40000000e+01   4.03000000e+02   9.61350000e-01   4.02040000e-02]
# [  1.50000000e+01   4.02000000e+02   9.58350000e-01   4.34600000e-02]
# [  1.60000000e+01   4.00000000e+02   9.52350000e-01   5.00340000e-02]
# [  1.70000000e+01   3.99000000e+02   9.49350000e-01   5.33520000e-02]
# [ 105.       268.         0.55635    0.79743]
# [ 106.        266.          0.55035     0.817026]
# [ 107.        264.          0.54435     0.837053]
# [ 108.        262.          0.53835     0.857528]
# [ 109.        260.          0.53235     0.878463]
# [ 110.        258.          0.52835     0.892685]
# [ 111.        255.          0.52235     0.914425]
# [ 112.        252.          0.51635     0.936671]
# [ 113.       249.         0.51035    0.95944]
# [ 114.       246.         0.50435    0.98275]
# [ 115.       243.         0.49835    1.00662]
# [ 116.       237.         0.48635    1.05613]
# [ 117.       234.         0.48035    1.08182]
# [ 118.       231.         0.47435    1.10815]
# [ 119.       228.         0.46835    1.13515]
# [ 120.       225.         0.46235    1.16286]
# [ 121.       222.         0.45635    1.1913 ]
# [ 122.       219.         0.45035    1.22049]
# [ 123.       216.         0.44435    1.25048]
# [ 124.       213.         0.43835    1.28128]
# [ 125.       210.         0.43235    1.31294]
# [ 126.       207.         0.42635    1.34549]
# [ 127.       204.         0.42035    1.37897]
# [ 128.       201.         0.41435    1.41342]
# [ 129.       198.         0.40835    1.44888]
# [ 130.       195.         0.40235    1.4854 ]
# [ 131.       192.         0.39635    1.52302]
# [ 132.       189.         0.39035    1.5618 ]
# [ 133.       186.         0.38435    1.60179]
# [ 134.       183.         0.37835    1.64305]
# [ 135.       180.         0.37235    1.68564]
# [ 136.       177.         0.36635    1.72963]
# [ 137.       174.         0.36035    1.77508]
# [ 138.       171.         0.35435    1.82207]
# [ 139.       168.         0.34835    1.87068]
# [ 140.       165.         0.34235    1.92099]
# [ 141.       162.         0.33635    1.97309]
# [ 142.       159.         0.33035    2.02709]
# [ 143.       156.         0.32435    2.08309]
# [ 144.       153.         0.31835    2.1412 ]
# [ 145.       150.         0.31235    2.20154]
# [ 146.       147.         0.30635    2.26424]
# [ 147.    144.      0.3     2.33]
# [ 148.       141.         0.29435    2.39732]
# [ 149.       138.         0.28835    2.46801]
# [ 150.       135.         0.28235    2.5417 ]
# [ 151.       132.         0.27635    2.6186 ]
# [ 152.       129.         0.27035    2.69891]
# [ 153.       126.         0.26435    2.78286]
# [ 154.       123.         0.25835    2.87072]
# [ 155.       120.         0.25235    2.96275]
# [ 156.       117.         0.24635    3.05926]
# [ 157.       111.         0.23435    3.26712]
# [ 158.       108.         0.22835    3.37924]
# [ 159.       105.         0.22235    3.49741]
# [ 160.       102.         0.21635    3.62214]
# [ 161.        99.         0.21035    3.75398]
# [ 162.        96.         0.20435    3.89356]
# [ 163.        95.         0.20235    3.94193]
# [ 164.        93.         0.19835    4.04159]
# [ 165.        90.         0.19235    4.19886]
# [ 166.        87.         0.18635    4.36625]
# [ 167.        84.         0.18035    4.54477]
# [ 168.        81.         0.17435    4.73559]
# [  1.69000000e+02   7.80000000e+01   1.68350000e-01   4.94001000e+00]
# [  1.70000000e+02   7.50000000e+01   1.62350000e-01   5.15953000e+00]
# [  1.71000000e+02   7.20000000e+01   1.56350000e-01   5.39591000e+00]
# [  1.72000000e+02   6.90000000e+01   1.50350000e-01   5.65115000e+00]
# [  1.73000000e+02   6.60000000e+01   1.44350000e-01   5.92761000e+00]
# [  1.74000000e+02   6.30000000e+01   1.38350000e-01   6.22804000e+00]
# [  1.75000000e+02   6.00000000e+01   1.32350000e-01   6.55572000e+00]
# [  1.76000000e+02   5.70000000e+01   1.26000000e-01   6.91000000e+00]
# [  1.77000000e+02   5.40000000e+01   1.20350000e-01   7.30910000e+00]
# [  1.78000000e+02   5.10000000e+01   1.14350000e-01   7.74508000e+00]
# [  1.79000000e+02   4.80000000e+01   1.08350000e-01   8.22935000e+00]
# [  1.80000000e+02   4.50000000e+01   1.02350000e-01   8.77040000e+00]
# [  1.81000000e+02   4.20000000e+01   9.63500000e-02   9.37883000e+00]
# [  1.82000000e+02   3.90000000e+01   9.03500000e-02   1.00681000e+01]
# [  1.83000000e+02   3.60000000e+01   8.43500000e-02   1.08554000e+01]
# [  1.84000000e+02   3.30000000e+01   7.80000000e-02   1.17600000e+01]
# [  1.85000000e+02   2.70000000e+01   6.60000000e-02   1.40700000e+01]
# [  1.86000000e+02   2.40000000e+01   6.00000000e-02   1.55700000e+01]
# [  1.87000000e+02   2.10000000e+01   5.40000000e-02   1.74000000e+01]

# %%
plot(data_points[:,1], data_points[:,2])

xlabel("${\mathrm{snapshot}}$", fontsize=20)
ylabel("$a_{\mathrm{exp}}$", fontsize=20)

# %%
sql_query="SELECT Mvir, Vcir, Rvir/conc, x, y, z FROM Bolshoi.BDMV WHERE snapnum=416 AND Mvir > 1.0E12 AND x < 30 AND y < 30 AND z < 30 ORDER BY Mvir desc"

# %%
job_id = CS.run_sql_query(query_string=sql_query)
# Out:
# Job created: 366231170364557

# %%
CS.check_job_status(jobid=job_id)
# Out:
# INFO:astropy:Job 366231170364557: COMPLETED
# INFO: Job 366231170364557: COMPLETED [astroquery.cosmosim.core]
# 'COMPLETED'

# %%
data = CS.download(jobid=job_id,format='csv')

# %%
header = data[0]
data_points = array(data[1])
print header
# Out:
# ['row_id', 'Mvir', 'Vcir', '_Rvir_/_conc_', 'x', 'y', 'z']

# %%
CS.download(jobid=job_id, filename='../data/Bolshoi_cube.csv',format='csv')

# %%
x=data_points[:,4]
y=data_points[:,5]
mass = data_points[:,1]
vcirc = data_points[:,2]

# %%
scatter(x,y)


xlabel("$x\ {\mathrm{[Mpc/h]}}$", fontsize=20)
ylabel("$y\ {\mathrm{[Mpc/h]}}$", fontsize=20)

# %%
scatter(log10(mass), log10(vcirc))


xlabel("$\log_{10} M/{\mathrm{M_\odot/h}}$", fontsize=20)
ylabel("$\log_{10} V_{c}/{\mathrm{km/s}}$", fontsize=20)
